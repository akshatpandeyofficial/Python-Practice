# %%
# if - else - elif  statement in Python

# %%
if 50>25:
    print("Yeah its Greater")
else :
    print("it isnt")
# Out:
# Yeah its Greater

# %%
if 5>25:
    print("Yeah its Greater")
else :
    print("it isnt")
# Out:
# it isnt

# %%
age = int(input("Enter Number : "))

if age >18 :
    print("Allowed to have a Driving Lisence")

elif age == 18  :
    print("You can Apply just after an Hour")

else: 
    print("Get The Fuck Out")
# Out:
# Enter Number :  0
# get The Fuck Out
