# %% [markdown]
# # BMI Calculator

# %%
name = input("Enter Your Name : ") 
age = int(input("Enter Age:"))
weight = int(input("Enter Your Weight in Pounds: "))
height = int(input("Enter Your Height in Inches: "))


BMI = (weight *703) / (height*height)
print(BMI)


if BMI >0:
    if (BMI <18.5):
        print( 'Hey!' +'  '+ name +'  '+ 'You are Underweight') 
    elif (BMI <24.9):
        print( 'Hey!' +'  '+ name  +'  '+ 'You are Normal Weight') 
    elif (BMI <29.9):
        print( 'Hey!' +'  '+ name  +'  '+ 'You are Overweight') 
    elif (BMI <34.9):
        print( 'Hey!' +'  '+ name  +'  '+ 'You are Obese') 
    elif (BMI <39.9):
        print( 'Hey!' +'  '+ name  +'  '+ 'you are Severely obese') 
else:
    print('Invalid Input')
# Out:
# Enter Your Name :  Akshat Pandey
# Enter Age: 19
# Enter Your Weight in Pounds:  136
# Enter Your Height in Inches:  70
# 19.511836734693876
# Hey!  Akshat Pandey  You are Normal Weight
