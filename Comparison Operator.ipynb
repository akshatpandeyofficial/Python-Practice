# %%
# Comparison Operators

# %%
x = 'Chocolate'
y = 'Vanilla'

x == y
# Out:
# False

# %%
x !=y
# Out:
# True

# %%
10 >=10
# Out:
# True

# %%
10<=10
# Out:
# True

# %%
# Logical Operators

# %%
(10 >50) and (50>10)
# Out:
# False

# %%
(10 >50) or (50>10)
# Out:
# True

# %%
('Vanilla' > 'Chocolate') and (50 > 20)
# Out:
# True

# %%
not(50>20)
# Out:
# False

# %%
#membership Operators

# %%
ice_cream = "there are Various Types of Ice Cream Flavours"

'Creamy' in ice_cream
# Out:
# False

# %%
scoop = [100,200,300,400,500]

101 in scoop
# Out:
# False

# %%
scoop = [100,200,300,400,500]

101 not in scoop
# Out:
# True
