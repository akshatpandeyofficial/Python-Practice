# %% [markdown]
# # WHILE LOOPS

# %%
num = 0

while num < 5 :
    print(num)
    num = num+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
num = 0

while num < 5:
    print(num)

    if num == 3:
        break

    num = num + 1
# Out:
# 0
# 1
# 2
# 3

# %%
num = 0 
while num < 5:
    print(num)

    if num ==6:
        break

    
    num = num+1
    
else:
        print('Invalid Statement')
# Out:
# 0
# 1
# 2
# 3
# 4
# Invalid Statement

# %%
num = 0

while num <5:
    num = num+1

    if num ==3:
        continue
    print(num)
    
else:
    print("Invalid Choice")
# Out:
# 1
# 2
# 4
# 5
# Invalid Choice
